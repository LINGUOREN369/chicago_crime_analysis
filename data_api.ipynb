# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("adelanseur/crimes-2001-to-present-chicago")

print("Path to dataset files:", path)

destination_folder = './MATH1756_Final_Project/data/chicago_crime'
shutil.move(path, destination_folder)
print(f"File moved to: {destination_folder}")
# Out:
# ...
# 100%|██████████| 436M/436M [01:03<00:00, 7.25MB/s]
# Extracting files...
# Path to dataset files: /Users/linguoren/.cache/kagglehub/datasets/adelanseur/crimes-2001-to-present-chicago/versions/1
# File moved to: ./MATH1756_Final_Project/data/chicago_crime

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./chicago_crime/Crimes_-_2001_to_Present.csv')

# %%
df.shape
df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  11646166    JC213529  09/01/2018 12:01:00 AM   082XX S INGLESIDE AVE  0810
# 1  11645836    JC212333  05/01/2016 12:25:00 AM     055XX S ROCKWELL ST  1153
# 2  11449702    JB373031  07/31/2018 01:30:00 PM  009XX E HYDE PARK BLVD  2024
# 3  11643334    JC209972  12/19/2018 04:30:00 PM  056XX W WELLINGTON AVE  1320
# 4  11645527    JC212744  02/02/2015 10:00:00 AM      069XX W ARCHER AVE  1153
#
#          Primary Type                          Description  \
# 0               THEFT                            OVER $500
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2           NARCOTICS                  POSS: HEROIN(WHITE)
# 3     CRIMINAL DAMAGE                           TO VEHICLE
# 4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0            RESIDENCE   False      True   631       6.0   8.0
# ...

# %%
pd.set_option('display.max_columns', None)

df_filtered = df[(df['Year'] >= 2020) & (df['Year'] <= 2024)]
df_filtered.to_csv('./chicago_crime/Crimes_2020-24.csv', index=False)
